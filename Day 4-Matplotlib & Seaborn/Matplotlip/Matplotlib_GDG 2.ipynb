# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Matplotlib
#
# Data Visualization:
#
# The process of finding trends and correlations in data by representing it pictorially is called Data Visualization.
#
# To perform data visualization in python, we can use various python data visualization modules such as Matplotlib, Seaborn, Plotly, Ggplot.

# %% [markdown]
# What is Matplotlib:
#
# ➤ Matplotlib is a plotting library for the Python programming language and its numerical mathematics
# extension NumPy.
#
# ➤ Matplotlib is a python library used for Data Visualization.
#
# ➤ Matplotlib is 2D and 3D plotting python library.
#
# ➤ It was introduced by john hunter in the year 2002.

# %% [markdown]
# Matplotlib Graphs:
#
# 1. Pairwise data: Plots of pairwise (x y), tabular (var_0,...var_n), and functional f(x) = y data:
#
# ➤ Line plot: plt.plot(x, y)
#
# ➤ Scatter plot: plt.scatter(x, y)
#
# ➤ Bar plot: plt.bar(x, y)
#
# ➤ Stem plot: plt.stem(x, y)
#
# ➤ Filled area between two horizontal curves: plt.fill_between(x, y1, y2)
#
# ➤ Stack plot: plt.stackplot(x, y)
#
# ➤ Step / Stairs plot: plt.stairs(x) / plt.step(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Statistical distributions: Plots of the distribution of at least one variable in a dataset. Some of
# these methods also compute the distributions.
#
# ➤ Histogram: plt.hist(X)
#
# ➤ Box plot: plt.boxplot(X)
#
# ➤ Error bar plot: plt.errorbar(x, y, yerr, xerr)
#
# ➤ Violin plot: plt.violinplot(D)
#
# ➤ Event plot: plt.eventplot(D)
#
# ➤ Hist2D plot: plt.hist2D(x, y)
#
# ➤ Hexbin plot: plt.hexbin(x, y, C)
#
# ➤ Pie plot: plt.pie(x)
#
# ➤ Empirical Cumulative Distribution Function: plt.ecdf(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Gridded data: Plots of arrays and images Z i,j and fields U i,j, Vi,j on regular grids and corresponding coordinate grids X i,j , Y i,j
#
# ➤ Display an image on the axes: plt.imshow(Z)
#
# ➤ Create a pseudocolor plot of a 2-D array: plt.pcolormesh([X, Y, Z]) / plt.pcolormesh(Z)
#
# ➤ Contour plot: plt.contour([X, Y, Z]) / plt.contour(Z)
#
# ➤ Filled contour plot: plt.contourf([X, Y, Z]) / plt.contourf(Z)
#
# ➤ Step plot: plt.step(x, y)
#
# ➤ Barbs plot: plt.barbs(X, Y, U, V)
#
# ➤ Quiver plot: plt.quiver(X, Y, U, V)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Irregularly gridded data: Plots of data Z x,y on unstructured grids, unstructured coordinate grids (x,y) and 2D functions f(x,y) = z
#
# ➤ Tricontour Plot: plt.tricontour(x, y, z)
#
# ➤ Tricontour filled with Plot: plt.
# tricontourf(x, y, z)
#
# ➤ Tri Pcolor Plot: plt.tripcolor(x, y, z)
#
# ➤ Tri Plot: plt.triplot(x, y)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. 3D and volumetric data: Matplotlib also supports 3D plots using the mpl_toolkits.mplot3d library.
#
# ➤ Scatter 3D: scatter(xs, ys, yz)
#
# ➤ Surface 3D: plot_surface(X, Y, Z)
#
# ➤ Trisurf 3D: plot_trisurf(x, y, z)
#
# ➤ Voxels 3D: voxels([x, y, z], field)
#
# ➤ Wireframe 3D: plot wireframe(X, Y, Z)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Install Matplotlib

# %% [markdown]
# Classes of Matplotlib:
#
# 1. Figure Class: This is the top-level container in this hierarchy. It is the overall window/page that everything is drawn on. Syntax: import matplotlib.figure
#
# 2. Axes Class: This is what we commonly think of as 'a plot'. A given figure can contain many Axes, but a given Axes object can only be in one Figure¹. The Axes contains two (or three in the case of3D) Axis objects which take care of the data limits. Syntax: import matplotlib.axes
#
# 3. Axis Class: These are the number-line-like objects and take care of setting the graph limits and generating the ticks (the marks on the axis) and ticklabels (strings labeling the ticks). Syntax: import matplotlib.axis
#
# 4. Artist Class: Basically, everything visible on the figure is an artist (even the Figure, Axes, and Axis objects). This includes Text objects, Line2D objects, collections objects, Patch objects. Syntax: import matplotlib.artist
#
# 5. Pyplot: Pyplot is a Matplotlib module that provides a MATLAB-like interface. Pyplot provides functions that interact with the figure i.e., creates a figure, decorates the plot with labels, etc.
# Syntax: import matplotlib.pyplot
#
# 6. Backend Layer Classes: These include FigureCanvas (the surface on which the figure will be drawn), Renderer (the class that takes care of drawing on the surface), and Event (handles mouse and keyboard events). Syntax: import matplotlib

# %% [markdown]
# Import Matplotlib

# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('/content/Local Household Socio-Economic Data.csv')
file.tail(4)
# Out:
#        Not_AvailableME_of_Responder  NUMBER_OF_MEMBERS_IN_HOUSEHOLD  \
# 206                   Ashish Chetri                               3
# 207  Ramesh BalakrishNot_Availablen                               5
# 208                   Aaditya Varma                               7
# 209                    Akhil Sharma                               3
#
#      AVG_HOUSEHOLD_INCOME                                      HOUSE_ADDRESS  \
# 206                 50000  32, 3, GopalNot_Availablegar Rd, Alipore, Kolk...
# 207                 90000  20, 2, GopalNot_Availablegar Rd, Alipore, Kolk...
# 208                 40000  32, GopalNot_Availablegar Rd, Alipore, Kolkata...
# 209                 25000  66, Chetla Rd, Chetla, Kolkata, West Bengal 70...
#
#     AGE_OF_MEMBERS  MALE_MEMBERS  FEMALE_MEMBERS  NO_OF_CHILDREN  \
# 206             34             1               2               0
# 207             37             3               2               1
# ...

# %%
# Getting the datatype of column
print
(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Not_AvailableME_of_Responder    210 non-null    object
#  1   NUMBER_OF_MEMBERS_IN_HOUSEHOLD  210 non-null    int64
#  2   AVG_HOUSEHOLD_INCOME            210 non-null    int64
#  3   HOUSE_ADDRESS                   210 non-null    object
#  4   AGE_OF_MEMBERS                  210 non-null    object
#  5   MALE_MEMBERS                    210 non-null    int64
#  6   FEMALE_MEMBERS                  210 non-null    int64
#  7   NO_OF_CHILDREN                  210 non-null    int64
#  8   STUDYING_CHILDREN               210 non-null    int64
#  9   NON_STUDYING_CHILDREN           210 non-null    int64
#  10  FOOD_CONSUMPTION_PATTERNS       208 non-null    object
#  11  EXPENDITURES                    210 non-null    int64
# ...

# %%
# to check if the dataset has any missing value
file.isna().sum()
# Out:
# Not_AvailableME_of_Responder      0
# NUMBER_OF_MEMBERS_IN_HOUSEHOLD    0
# AVG_HOUSEHOLD_INCOME              0
# HOUSE_ADDRESS                     0
# AGE_OF_MEMBERS                    0
# MALE_MEMBERS                      0
# FEMALE_MEMBERS                    0
# NO_OF_CHILDREN                    0
# STUDYING_CHILDREN                 0
# NON_STUDYING_CHILDREN             0
# FOOD_CONSUMPTION_PATTERNS         2
# EXPENDITURES                      0
# HOUSEHOLD_ASSETS                  0
# Fridge                            0
# AC                                0
# Personal_Vehicle                  0
# Washing_Machine                   0
# TV                                0
# SOURCES_OF_WATER                  1
# AVAILABILITY_OF_SMART_DEVICES     0
# Desktop_Laptop                    0
# Phone                             0
# Other_SmartDevices                0
# ACCESS_TO_INTERNET                0
# ANY_PREDOMINANT_AILMENT           0
# dtype: int64

# %%
# Male members in every household and that numbers
male = file.MALE_MEMBERS.value_counts()
print(male)
# Out:
# MALE_MEMBERS
# 2    89
# 1    66
# 3    35
# 4     8
# 0     7
# 5     4
# 6     1
# Name: count, dtype: int64

# %%
# Max male members in household
max = file.MALE_MEMBERS.value_counts().max()
print(max)
# Out:
# 89

# %%
# Viewing the particular number of male member
par = (file.MALE_MEMBERS == 4).sum()
print(par)
# Out:
# 8

# %% [markdown]
# Linking another dataset for visualization

# %%
df_car = pd.read_csv('/content/test.csv')
df_car.head(4)
# Out:
#       id          brand                                              model  \
# 0  54273  Mercedes-Benz                                      E-Class E 350
# 1  54274          Lexus                                        RX 350 Base
# 2  54275  Mercedes-Benz                                      C-Class C 300
# 3  54276           Land  Rover Range Rover 5.0L Supercharged Autobiogra...
#
#    model_year  milage fuel_type  \
# 0        2014   73000  Gasoline
# 1        2015  128032  Gasoline
# 2        2015   51983  Gasoline
# 3        2018   29500  Gasoline
#
#                                           engine  \
# 0  302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  275.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 2   241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3   518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T   White   Beige
# 1                     8-Speed A/T  Silver   Black
# ...

# %% [markdown]
# Here are some of the functions in matplotlib.pyplot that are used to set properties and customizing the appearance of plot:
#
#
#
# 1. plt.title(): This function is used to set a title for the plot.
#
# 2. plt.xlabel(): This function is used to set a label for the x-axis.
#
# 3. plt.ylabel(): This function is used to set a label for the y-axis.
#
# 4. plt.axis(): This function is used to get or set some axis properties.
#
# 5. plt.xticks(): This function is used to get or set the current tick locations and labels of the x-axis.
#
# 6. plt.yticks(): This function is used to get or set the current tick locations and labels of the y-axis.
#
# 7. plt.grid(): This function is used to configure the grid lines.
#
# 8. plt.legend(): This function places a legend on the axes.
#
# 9. plt.figure(): This function creates a new figure, or activates an existing figure.
#
# 10. plt.show(): This function displays a figure.
#
# 11. plt.colorbar(): This will show a color pallate in scatter plot

# %% [markdown]
# Line Plot
#
# Syntax: plt.plot(x,y), where x and y can be list or tuple
# The plt.plot() function in matplotlib.pyplot has the following parameters:
#
# 1. args: This is a variable length argument, allowing for multiple x, y pairs with an optional format string.
#
# 2. scalex, scaley: These are optional boolean values that, when set to True (default), will autoscale the x and/or y axis.
#
# 3. data: This is an optional parameter where you can pass a DataFrame.
#
# 4. color: color or list of color, optional. The colors of the line
# faces.
#
# 5. linewidth: float or array-like, optional. Width of the line edges.
#
# 6. label: str or list of str, optional. A label for the whole dataset or individual lines.

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Data for the plot
names = ('Mohamed', 'Ahmed', 'El-sadek')
marks = [96, 80, 60]

# Plot the data
plt.plot(names, marks,
         color='y',  # Line color
         label='Marks',  # Label for the legend
         linewidth=4,  # Line width
         scalex=True,  # Enable scaling for the x-axis (default is True)
         scaley=True)  # Enable scaling for the y-axis (default is True)

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
# Evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# Plot multiple lines using *args
plt.plot(t, t, 'r--',  # Red dashed line
         t, t**2, 'bo',  # Blue circles
         t, t**3, 'g^')  # Green triangles

''' Explanation:
- The first argument in each triplet is the x-axis data (t).
- The second argument is the y-axis data (t, t**2, t**3).
- The third argument specifies the line style or marker:
  - 'r--': Red dashed line
  - 'bo': Blue circles
  - 'g^': Green triangles
'''

# Display the plot
plt.show()

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Define data as a dictionary
data = {'a': [1, 2, 3, 4], 'b': [2, 3, 5, 7]}

# Plot 'b' against 'a' using the 'data' parameter
plt.plot('a', 'b', data=data)

# Display the plot
plt.show()
# Out:
# <ipython-input-13-edf905481956>:8: RuntimeWarning: Second argument 'b' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('a', 'b', data=data)

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]
student2_marks = [65, 78, 96, 85]

# Plot the marks of Student 1 and Student 2
plt.plot(subjects, student1_marks, label='Student 1')  # Line plot for Student 1
plt.plot(subjects, student2_marks, label='Student 2')  # Line plot for Student 2

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
# Define data
date = ('21/2/2023', '14/03/2024', '14/02/2025')
Cholestoral_Total = [181, 99, 86]
Trigllycarides = [109, 92, 69]
HDL_Cholestoral = [51, 39, 35]
LDL_Cholestoral = [109, 41, 37]
VLDL_Cholestoral = [22, 18, 14]
Non_HDL_Cholestoral = [131, 60, 51]

# Plot each data series with markers and labels
plt.plot(date, Cholestoral_Total, marker='o', color='y', label='Cholestoral, Total')
plt.plot(date, Trigllycarides, marker='o', color='r', label='Trigllycarides')
plt.plot(date, HDL_Cholestoral, marker='o', color='g', label='HDL Cholestoral')
plt.plot(date, LDL_Cholestoral, marker='o', color='b', label='LDL Cholestoral')
plt.plot(date, VLDL_Cholestoral, marker='o', color='deeppink', label='VLDL Cholestoral')
plt.plot(date, Non_HDL_Cholestoral, marker='o', color='purple', label='Non-HDL Cholestoral')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Extract counts of male and female members from the file
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
x = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
y = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# Define x-axis values (categories or groups)
num = range(len(categories))  # Use indices for the x-axis

# Plot male and female counts
plt.plot(num, x, color='b', label='Male')  # Blue line for male members
plt.plot(num, y, color='r', label='Female')  # Red line for female members

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Scatter Plot
#
#
# Syntax: plt.scatter(x,y), where x and y can be list or tuple
# The plt.scatter() function in matplotlib.pyplot has the following parameters:
#
#
# 1. x, y: These are arrays or sequences of n numbers representing the data positions. This defines dot size
#
#
# 2. s: This is the marker size in points**2. It can be a scalar or an array-like shape (n,), and is optional.
#
#
# 3. c or color: This represents the marker colors. It can be an array-like or list of colors or color, and is optional.
#
#
# 4. marker: This is the marker style. It can be either an instance of the class or the text shorthand for a particular marker.
#
#
# 5. cmap: This is the Colormap instance or registered colormap name used to map scalar data to colors.
#
#
# 6. norm: This is the normalization method used to scale scalar data to the [0, 1] range before mapping to colors using cmap.
#
#
# 7. vmin, vmax: These are used in conjunction with norm to normalize luminance data.
#
#
# 8. alpha: This is the alpha blending value, between 0 (transparent) and 1 (opaque).
#
#
# 9. linewidths: This is the linewidth of the marker edges.
#
#
# 10. edgecolors: This is the color or sequence of colors of the marker edges.
#
#
# 11. plotnonfinite: This boolean value is used to indicate whether to plot the non-finite x, y values.
#
#
# 12. data: This is an optional parameter that can be a DataFrame.

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Define data
name = ('ElSany', 'Hamdi', 'Ahmed')
marks = [96, 80, 60]

# Create a scatter plot
plt.scatter(name, marks)

# Display the plot
plt.show()

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Define data
name = ('ElSany', 'Hamdi', 'Ahmed')
marks = [96, 80, 60]
colors = ['r', 'g', 'b']  # List of colors for each point

# Create a scatter plot with customizations
plt.scatter(name, marks,
            c=colors,  # Color for each point
            s=80,  # Size of the markers
            marker='*',  # Star-shaped markers
            alpha=0.6,  # Transparency of the markers
            edgecolor='black',  # Edge color of the markers
            linewidth=2,  # Width of the marker edges
            plotnonfinite=True)  # Handle non-finite values (not critical here)

# Add a color bar (optional, but not meaningful in this case since colors are categorical)
plt.colorbar()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Generate random data
N = 40  # Number of points
x = np.random.rand(N)  # Random x-values
y = np.random.rand(N)  # Random y-values
colors = np.random.rand(N)  # Random color values

# Define normalization for the colormap
n = mcolors.Normalize(vmin=-2., vmax=2.)  # Normalize colors between -2 and 2

# Create a scatter plot with colormap and normalization
plt.scatter(x, y, c=colors, norm=n, cmap='viridis')  # Use 'viridis' colormap

# Add a color bar to show the mapping of colors to values
plt.colorbar()

# Display the plot
plt.show()

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Create a DataFrame with random data
df = pd.DataFrame({
    'a': np.random.randn(1000),  # Random data for column 'a'
    'b': np.random.randn(1000),  # Random data for column 'b'
    'c': np.random.randn(1000)   # Random data for column 'c'
})

# Create a scatter plot using DataFrame columns
plt.scatter('a', 'b', c='c', data=df)  # 'a' and 'b' are x and y, 'c' determines color

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]
student2_marks = [65, 78, 96, 85]

# Plot std1 and std2 against subjects
plt.scatter(subjects, student1_marks, label='Student 1')  # Scatter plot for Student 1
plt.scatter(subjects, student2_marks, label='Student 2')  # Scatter plot for Student 2

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Bar Plot
#
#
# Syntax: plt.bar(x,y), where x and y can be list or tuple
# The plt.bar() function in matplotlib.pyplot has the following parameters:
#
#
# 1. x: Float or array-like. The x coordinates of the bars.
#
#
# 2. height / y: Float or array-like. The heights of the bars.
#
#
# 3. width: Float or array-like, default: 0.8. The widths of the bars.
#
#
# 4. bottom: Float or array-like, default: 0. The y coordinates of the bottom sides of the bars.
#
#
# 5. align: {'center', 'edge'}, default: 'center'. Alignment of the bars to the x coordinates.
#
#
# 6. color: color or list of color, optional. The colors of the bar faces.
#
#
# 7. edgecolor: color or list of color, optional. The colors of the bar edges.
#
#
# 8. linewidth: float or array-like, optional. Width of the bar edges.
#
#
# 9. linestyle: Style of the bar graph. It can be "solid", "dotted", "dashed" or "dashdot". By default it's solid.
#
#
# 10. tick_label: str or list of str, optional. The tick labels of the bars.
#
#
# 11. label: str or list of str, optional. A label for the whole dataset or individual bars.
#
#
# 12. alpha: It's control the opacity of bar graph
#
#
# 13. xerr, yerr: float or array-like of shape (N,) or shape (2, N), optional. Add horizontal/vertical errorbars to the bar tips.

# %%
# Create a figure with a specific size and DPI
fig = plt.figure(figsize=(3, 2), dpi=150)

# Define data
name = ('ElSany', 'Hamdi', 'Ahmed')
marks = [96, 80, 60]

# Create a bar plot
plt.bar(name, marks)

# Display the plot
plt.show()

# %%
# Define data
name = ('ElSany', 'Hamdi', 'Ahmed')
marks = [96, 80, 60]
bottom = (2, 1, 2)  # Bottom offsets for the bars
colors = ['r', 'g', 'b']  # Colors for the bars
tick_labels = ('Name: ElSany', 'Name: Hamdi', 'Name: Ahmed')  # X-axis tick labels
labels = ('ElSany', 'Hamdi', 'Ahmed')  # Legend labels

# Create a bar plot with customizations
plt.bar(name, marks,
        bottom=bottom,  # Bottom offsets for the bars
        align='edge',  # Align bars to the edge of the x-axis ticks
        width=0.6,  # Width of the bars
        color=colors,  # Colors for the bars
        alpha=0.6,  # Transparency of the bars
        edgecolor='black',  # Edge color of the bars
        linewidth=2,  # Width of the bar edges
        linestyle="dotted",  # Line style of the bar edges
        tick_label=tick_labels,  # Custom x-axis tick labels
        label=labels)  # Labels for the legend

# Add a legend to the plot
plt.legend(loc='center')  # Place the legend at the center of the plot

# Display the plot
plt.show()

# %%
# Define data
name = ('ElSany', 'El-sadek', 'Ahmed')
marks = [96, 80, 60]
x_error = (1, 2, 3)  # Error values for the x-axis
y_error = (3, 2, 1)  # Error values for the y-axis

# Create a bar plot with error bars
plt.bar(name, marks, xerr=x_error, yerr=y_error)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
name = ('Subha', 'Subhajit Das', 'Subhajit')
marks = [96, 80, 60]
total = [450, 420, 375]

# Plot overlapping bars
plt.bar(name, total, color='skyblue', width=0.6, label='Total Marks')  # Light blue for total marks
plt.bar(name, marks, color='orange', width=0.6, label='Computer Marks')  # Orange for computer marks

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
name = ('Subha', 'Subhajit Das', 'Subhajit')
marks = [96, 80, 60]
total = [450, 420, 375]
width = 0.4  # Width of the bars

# Create positions for the bars
n1 = np.arange(len(name))  # Positions for the first set of bars
n2 = [i + width for i in n1]  # Positions for the second set of bars (shifted by width)

# Plot horizontal bars
plt.barh(n1, total, width, color='skyblue', label='Total Marks')  # Light blue for total marks
plt.barh(n2, marks, width, color='orange', label='Computer Marks')  # Orange for computer marks

# Set y-axis ticks and labels
plt.yticks(n1 + width / 2, name, rotation=10)  # Place labels between the bars and rotate them slightly

# Add padding between the y-axis labels and the plot
plt.tight_layout()

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(8, 6), dpi=150)  # Increased figure size

# Define data
date = ('21/11/2022', '14/03/2022', '26/08/2023')
Cholestoral_Total = [181, 99, 86]
Trigllycarides = [109, 92, 69]
HDL_Cholestoral = [51, 39, 35]
LDL_Cholestoral = [109, 41, 37]
VLDL_Cholestoral = [22, 18, 14]
Non_HDL_Cholestoral = [131, 60, 51]

# Define width and positions for the bars
width = 0.12
n1 = np.arange(len(date))  # Base positions for the first set of bars
n2 = [i + width for i in n1]  # Positions for the second set of bars
n3 = [i + width for i in n2]  # Positions for the third set of bars
n4 = [i + width for i in n3]  # Positions for the fourth set of bars
n5 = [i + width for i in n4]  # Positions for the fifth set of bars
n6 = [i + width for i in n5]  # Positions for the sixth set of bars

# Set y-axis ticks and labels
plt.yticks(n1 + width * 2.5, date, rotation=0, fontsize=10)  # Place labels between the bars and adjust font size

# Plot horizontal bars
plt.barh(n1, Cholestoral_Total, width, color='skyblue', label='Cholestoral, Total')
plt.barh(n2, Trigllycarides, width, color='orange', label='Trigllycarides')
plt.barh(n3, HDL_Cholestoral, width, color='green', label='HDL Cholestoral')
plt.barh(n4, LDL_Cholestoral, width, color='blue', label='LDL Cholestoral')
plt.barh(n5, VLDL_Cholestoral, width, color='deeppink', label='VLDL Cholestoral')
plt.barh(n6, Non_HDL_Cholestoral, width, color='purple', label='Non-HDL Cholestoral')

# Invert the y-axis to reverse the order of dates
plt.gca().invert_yaxis()

# Add a legend to the plot
plt.legend(loc='upper right')

# Add grid lines for better readability
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the y-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(4, 5), dpi=150)  # Adjusted figure size

# Define data
total_income = file['AVG_HOUSEHOLD_INCOME'].sum()
total_expense = file['EXPENDITURES'].sum()
money = 'Income and Expense in Rs.'

# Print total income and expense
print(f'Total income is: {total_income}')
print(f'Total expense is: {total_expense}')
print()

# Plot bars for total income and expense
plt.bar(money, total_income, color='skyblue', width=0.4, label='Total Income')  # Light blue for income
plt.bar(money, total_expense, color='orange', width=0.4, label='Total Expense')  # Orange for expense

# Add a legend to the plot
plt.legend(loc='lower center')

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# Total income is: 11743000
# Total expense is: 7285500

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(5, 4), dpi=150)  # Increased figure size

# Define data
money = ['Income', 'Expenses']
total = [total_income, total_expense]
colors = ['skyblue', 'orange']  # Custom colors for income and expenses

# Plot bars for income and expenses
plt.bar(money, total, color=colors)

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Stem Plot
#
#
# Syntax: plt.stem(x,y) / plt.stem(y,x), where x and y can be list or tuple
#
# The plt.stem() function in matplotlib.pyplot has the following parameters:
#
# 1. locs, x/y: The x or y positions of the stem heads.
#
# 2. heads, x/y: The y or x positions of the stem heads.
#
# 3. linefmt: A string defining the color and style of the vertical lines.
#
# 4. markerfmt: A string defining the color and style of markers.
#
# 5. basefmt: A format for the baseline.
#
# 6. bottom: The y-position of the baseline.
#
# 7. use_line_collection: A boolean value indicating whether to create the stem lines as a LineCollection instead of individual lines.
#
# 8. orientation: If 'vertical', will produce a plot with stems oriented vertically, If 'horizontal', the stems will be oriented horizontally

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Create a horizontal stem plot
plt.stem(subjects, student1_marks, linefmt='skyblue', markerfmt='o', basefmt='gray')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(5, 6), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Create a vertical stem plot
plt.stem(student1_marks, subjects, linefmt='skyblue', markerfmt='o', basefmt='gray', orientation='horizontal')

# Customize y-axis labels for better readability
plt.yticks(fontsize=10)  # Adjust font size for y-axis labels

# Add padding between the y-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
num = [0, 1, 2, 3]
x = [20, 40, 60, 35]  # Positive values
y = [-40, -45, -30, -55]  # Negative values

# Create stem plots for positive and negative values
plt.stem(num, x, linefmt='skyblue', markerfmt='o', basefmt='gray', label='Positive Values')
plt.stem(num, y, linefmt='orange', markerfmt='s', basefmt='gray', label='Negative Values')

# Add a legend to the plot
plt.legend()

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Create a stem plot with custom parameters
plt.stem(subjects, student1_marks,
         linefmt='r-.',  # Red dashed-dotted line for stems
         markerfmt='bs',  # Blue square markers
         bottom=1,  # Plot stems starting from y=1
         basefmt='k--',  # Black dashed baseline
         orientation='vertical',  # Vertical orientation (default)
         label='Marks')  # Label for the legend

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
x = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
y = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# X-axis positions
num = range(len(categories))

# Create stem plots for male and female members
plt.stem(num, x, linefmt='skyblue', markerfmt='o', basefmt='gray', label='Male Members')
plt.stem(num, y, linefmt='orange', markerfmt='s', basefmt='gray', label='Female Members')

# Add a legend to the plot
plt.legend()

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Filled area between two horizontal curves:
#
#
# plt.fill_between(x, y1, y2)/ plt.plot(x,y) plt.fill_between(), where x and y can be list or tuple The plt.fill_between() function in matplotlib.pyplot has the following parameters:
#
#
# 1. x: An array of length N representing the x-coordinates of the nodes defining the curves.
#
#
# 2. y1: An array of length N or a scalar representing the y-coordinates of the nodes defining the first curve.
#
#
# 3. y2: An array of length N or a scalar (default: 0) representing the y-coordinates of the nodes defining the second curve.
#
#
# 4. color: Color or array-like of color, default: None.
#
#
# 5. where: An array of boolean values of length N (optional) used to exclude some horizontal regions from being filled.
#
#
# 6. interpolate: An optional boolean parameter (default: False) that is relevant if where is used and the two curves are crossing each other.
#
#
# 7. step: An optional parameter that accepts one of the three values: 'pre', 'post', or 'mid'. It specifies where the steps will occur.

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Plot the line and fill the area beneath it
plt.plot(subjects, student1_marks, color='skyblue', label='Student 1 Marks')  # Line plot
plt.fill_between(subjects, student1_marks, color='skyblue', alpha=0.3)  # Filled area

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Plot the line and fill the area beneath it
plt.plot(subjects, student1_marks, color='blue', label='Student 1 Marks')  # Line plot
plt.fill_between(subjects, student1_marks,
                 color='orange',  # Fill color
                 step='mid',  # Step style: 'mid' (other options: 'pre', 'post')
                 alpha=0.3,  # Transparency of the fill
                 label='Filled Area')  # Label for the legend

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

# Plot the line
plt.plot(x, y, color='red', label='y = x')  # Line plot

# Fill the area between x=2 and x=4
plt.fill_between(x, y,
                 color='green',  # Fill color
                 where=(x >= 2) & (x <= 4),  # Condition for filling
                 alpha=0.3,  # Transparency of the fill
                 label='Filled Area (2 ≤ x ≤ 4)')  # Label for the legend

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add a legend to the plot
plt.legend()

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]
student2_marks = [65, 78, 96, 85]

# Fill the area between the two curves
plt.fill_between(subjects, student1_marks, student2_marks,
                 color='skyblue',  # Fill color
                 alpha=0.3,  # Transparency of the fill
                 label='Area between Student 1 and Student 2')  # Label for the legend

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
x = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
y = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# X-axis positions
num = range(len(categories))

# Plot lines for male and female members
plt.plot(num, x, color='red', label='Male Members')  # Red line for male members
plt.plot(num, y, color='blue', label='Female Members')  # Blue line for female members

# Fill the area between the two lines
plt.fill_between(num, x, y, color='green', alpha=0.3, label='Area between Male and Female')  # Green fill

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(num, categories, rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Stack Area Plot:
#
#
# plt.stackplot(x, y), where x and y can be list or tuple
# The plt.stackplot() function in matplotlib.pyplot has the following parameters:
#
# 1. x: a 1-D array of values.
#
#
# 2. y: a 2-D array of values. The data is assumed to be unstacked. Each of the following calls is legal:
#
# stackplot(x, y) where y has shape (M, N) or stackplot(x, y1, y2, y3) where y1, y2, y3, y4 have length N.
#
#
# 3. labels: A sequence of labels to assign to each data series.
#
# 4. colors: A sequence of colors to be cycled through and used to color the stacked areas.
#
# 5. baseline: Method used to calculate the baseline. It can be ‘zero’, ‘sym’, ‘wiggle’, 'weighted_wiggle’.
#
# 6. data: If given, all parameters also accept a string s, which is interpreted as data [s] (unless this raises an exception).
#
# The baseline parameter is used to denote the method used to calculate the baseline:
#
#
# zero: Constant zero baseline, i.e., a simple stacked plot.
#
# sym: Symmetric around zero and is sometimes called 'ThemeRiver’.
#
#
# wiggle: Minimizes the sum of the squared slopes.
#
# weighted_wiggle: Does the same but weights to account for the size of each layer. It is also called ‘Streamgraph’-layout

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
subjects = ["Machine Learning", "Maths", "Deep Learning", "NLP"]
student1_marks = [92, 88, 60, 72]

# Create a single stack plot
plt.stackplot(subjects, student1_marks, colors=['skyblue'], labels=['Student 1 Marks'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
x = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
y = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# X-axis positions
num = range(len(categories))

# Create a stack plot for male and female members
plt.stackplot(num, x, y, colors=['skyblue', 'orange'], labels=['Male Members', 'Female Members'])

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(num, categories, rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
x = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
y = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# X-axis positions
num = range(len(categories))

# Labels and colors
labels = ['Male', 'Female']
colors = ['green', 'red']

# Create a stack plot with custom parameters
plt.stackplot(num, x, y,
              labels=labels,  # Labels for the legend
              colors=colors,  # Colors for the stacks
              baseline='weighted_wiggle')  # Baseline method for stacking

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(num, categories, rotation=45, ha='right')  # Rotate labels and align them to the right

# Add a legend to the plot
plt.legend()

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# 2. Statistical distributions
#
# Histogram:
#
# plt.hist(x)
#
# The plt.hist() function in matplotlib.pyplot has the following parameters:
#
#
# 1. x: This is the sequence of data that you want to plot in the histogram.
#
#
# 2. bins: This can be an integer, sequence, or string. If an integer, it defines the number of equal-width bins in the range. If a sequence, it defines the bin edges.
#
#
# 3. range: This is the lower and upper range of the bins.
#
#
# 4. density: If True, the function will draw and return a probability density.
#
#
# 5. weights: This is an array of weights, of the same shape as x.
#
#
# 6. cumulative: If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values.
#
#
# 7. bottom: This is the location of the bottom baseline of each bin.
#
#
# 8. histtype: This parameter is used to draw type of histogram. Options include ‘bar’, ‘barstacked’, ‘step’, 'stepfilled’.
#
#
# 9. align: This controls how the histogram is plotted. Options include ‘left’, ‘mid’, 'right’.
#
#
# 10. orientation: This controls the orientation of the histogram. Options include ‘horizontal’, 'vertical’.
#
#
# 11. rwidth: This is the relative width of the bars as a fraction of the bin width.
#
#
# 12. log: If True, the histogram axis is set to a log scale.
#
#
# 13. edgecolors: This is the color or sequence of colors of the marker edges.
#
#
# 14. color: This is a color spec or sequence of color specs, one per dataset.
#
#
# 15. label: This is a string, or sequence of strings to match multiple datasets.
#
#
# fig = plt.figure(figsize=(3, 2), dpi=150)
# # Viewing male and female step graph
# x = file.MALE_MEMBERS.value_counts().values
# y = file.FEMALE_MEMBERS.value_counts().values
# num = [0, 1, 2, 3, 4, 5, 6]
# # Create a step plot.
# plt.step(num, x, label = 'Male')
# plt.step(num, y, label = 'Female')
# plt.legend()
# plt.grid() # It will show grid in background 38
#
#
# 16. stacked: If True, multiple data are stacked on top of each other If false multiple data are arranged side by side if histtype is ‘bar’ or on top of each other if histtype is 'step’.
#
#
# 17. data: This parameter is used when the x values are a string, in which case this should be a data object that the string can be looked up in

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
income = file.AVG_HOUSEHOLD_INCOME.value_counts().values

# Create a histogram
plt.hist(income, bins=10, color='skyblue', edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title('Distribution of Average Household Income')
plt.xlabel('Average Household Income')
plt.ylabel('Frequency')

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
income = file.AVG_HOUSEHOLD_INCOME.value_counts().values

# Create a histogram with custom parameters
plt.hist(income,
         bins=8,  # Number of bins (range divided into 8 equal-width bins)
         range=(0, 28),  # Range of the data (from 0 to 28)
         density=True,  # Normalize the histogram (area sums to 1)
         cumulative=True,  # Cumulative distribution (default: False)
         histtype='barstacked',  # Type of histogram ('bar', 'barstacked', 'step', 'stepfilled')
         alpha=1,  # Transparency of the bars (1 = fully opaque)
         align='mid',  # Alignment of the bars ('left', 'mid', 'right')
         orientation='horizontal',  # Orientation of the histogram ('vertical' or 'horizontal')
         rwidth=0.8,  # Relative width of the bars (0.8 = 80% of the bin width)
         edgecolor='r',  # Edge color of the bars (red)
         color='g',  # Fill color of the bars (green)
         stacked=False)  # Stack multiple datasets (default: False)

# Add titles and labels
plt.title("Avg Household Income")
plt.xlabel("Income")
plt.ylabel("Num of Persons")

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
x = file.MALE_MEMBERS.value_counts().values  # Counts of male members
y = file.FEMALE_MEMBERS.value_counts().values  # Counts of female members

# Create histograms for male and female members
plt.hist(x, bins=10, color='skyblue', edgecolor='black', alpha=0.7, label='Male')
plt.hist(y, bins=10, color='orange', edgecolor='black', alpha=0.7, label='Female')

# Add a vertical line at x=30
plt.axvline(30, color='red', linestyle='--', label='Gender Line')

# Add titles and labels
plt.title('Distribution of Male and Female Members')
plt.xlabel('Number of Members')
plt.ylabel('Frequency')

# Add a legend to the plot
plt.legend()

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Box plot:
#
#
# plt.boxplot(X)
#
#
# The plt.box() function in matplotlib.pyplot has the following parameters:
#
#
#
# 1. data: array or sequence of array to be plotted
#
# 2. notch: optional parameter accepts boolean values
#
# 3. vert: optional parameter accepts boolean values false and true for horizontal and vertical plot respectively
#
# 4. bootstrap: optional parameter accepts int specifies intervals around notched boxplots
#
# 5. usermedians: optional parameter accepts array or sequence of array dimension compatible with data
#
# 6. positions: optional parameter accepts array and sets the position of boxes
#
# 7. widths: optional parameter accepts array and sets the width of boxes
#
# 8. patch_artist: optional parameter having boolean values
#
# 9. labels: sequence of strings sets label for each dataset
#
# 10. meanline: optional having boolean value try to render meanline as full width of box
#
# 11. order: optional parameter sets the order of the boxplot
#
# 12. showmeans: It will show the mean position
#
# 13. sym: To change the outliers color
#
# 14. boxprops: To change the box color
#
# 15. capprops: To change the line color
#
# 16. whiskerprops: To change the whisker color

# %% [markdown]
# ![WhatsApp Image 2025-01-24 at 04.22.34_705957fc.jpg](data:image/jpeg;base64,...)

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
ril = [2345, 2356, 2376, 2384]

# Create a box plot
plt.boxplot(ril, showmeans=True)  # Show the mean value in the box plot

# Add titles and labels
plt.title('Box Plot of RIL Data')
plt.ylabel('Values')

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
ril = [2345, 2356, 2376, 2384, 2200]  # Includes an outlier (2200)

# Create a box plot with custom outlier style
plt.boxplot(ril,
            sym='r+')  # Customize the outlier symbol (red plus sign)

# Add titles and labels
plt.title('Box Plot of Reliance Share Price')
plt.ylabel('Share Price')

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(6, 4), dpi=150)  # Increased figure size

# Define data
ril = [2345, 2356, 2376, 2384]

# Create a customized box plot
plt.boxplot(ril,
            notch=True,  # Add a notch to the box plot to show confidence intervals
            vert=False,  # Horizontal box plot (default: vertical)
            widths=0.4,  # Width of the box (default: 0.2)
            bootstrap=1000,  # Number of bootstrap samples for confidence intervals
            patch_artist=True,  # Fill the box with color
            labels=["Reliance Industry"],  # Label for the box plot
            boxprops=dict(color='r', facecolor='g'),  # Box properties (red edge, green fill)
            capprops=dict(color='g'),  # Cap properties (green color)
            whiskerprops=dict(color='pink'))  # Whisker properties (pink color)

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# <ipython-input-60-c07bd4b9db8e>:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(ril,

# %%
# Create a figure with a larger size to accommodate the labels
fig = plt.figure(figsize=(8, 5), dpi=150)  # Increased figure size

# Define data
day_1 = [2356, 2382, 2422, 2428]
day_2 = [2360, 2364, 2375, 2391]
day_3 = [2345, 2356, 2376, 2384]
ril = [day_1, day_2, day_3]

# Create a customized box plot
plt.boxplot(ril,
            patch_artist=True,  # Fill the boxes with color
            labels=['20/09/2023', '21/09/2023', '22/09/2023'],  # X-axis labels
            boxprops=dict(color='green', facecolor='red'))  # Box properties (green edge, red fill)

# Add titles and labels
plt.title("Reliance Industry Share Price")
plt.xlabel("Date")
plt.ylabel("Share Price")

# Add grid lines
plt.grid(color='gray', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them to the right

# Add padding between the x-axis labels and the plot
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# <ipython-input-61-d5fc261c0540>:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(ril,

# %% [markdown]
# Pie Plot
#
# Syntax: plt.pie(x), where x can be list or tuple
# The plt.pie() function in matplotlib.pyplot has the following parameters:
#
#
# 1. x: 1D array-like. The wedge sizes.
#
#
# 2. explode: array-like, default: None. Specifies the fraction of the radius with which to offset each wedge.
#
#
# 3. labels: list, default: None. A sequence of strings providing the labels for each wedge.
#
#
# 4. colors: color or array-like of color, default: None. A sequence of colors through which the pie chart will cycle.
#
#
# 5. autopct: None or str or callable, default: None. If not None, autopct is a string or function used to label the wedges with their numeric value.
#
#
# 6. pctdistance: float, default: 0.6. The relative distance along the radius at which the text generated by autopct is drawn.
#
# 7. labeldistance: float or None, default: 1.1. The relative distance along the radius at which the labels are drawn.
#
#
# 8. shadow: bool or dict, default: False. If bool, whether to draw a shadow beneath the pie. import matplotlib.pyplot as plt
#
# 9. startangle: float, default: 0 degrees. The angle by which the start of the pie is rotated, counterclockwise from the x-axis.
#
# 10. radius: float, default: 1. The radius of the pie.
#
# 11. counterclock: bool, default: True. Specify fractions direction, clockwise or counterclockwise.
#
# 12. wedgeprops: dict, default: None. Dict of arguments passed to each patches.Wedge of the pie.
#
# 13. textprops: dict, default: None. Dict of arguments to pass to the text objects.
#
# 14. center: (float, float), default: (0, 0). The coordinates of the center of the chart.
#
# 15. frame: bool, default: False. Plot Axes frame with the chart if true.
#
# 16. rotatelabels: bool, default: False.
#
# 17. hatch: str or list, default: None. Hatching pattern applied to all pie wedges or sequence of patterns through which the chart will cycle.
#
# 18. normalize: bool, default: True .
#
# 19. data: array-like, optional

# %%
# Create a pie chart with a single value
plt.pie([1])

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with a larger size to accommodate the labels
plt.figure(1, figsize=(6, 6))  # Increased figure size

# Define data
labels = file.MALE_MEMBERS.value_counts().index  # Labels for the pie chart
counts = file.MALE_MEMBERS.value_counts().values  # Values for the pie chart

# Define custom colors
colors = ['skyblue', 'orange', 'lightgreen', 'pink', 'lightcoral']

# Create a pie chart with customizations
plt.pie(counts,
        labels=labels,  # Add labels
        colors=colors,  # Set custom colors
        autopct='%1.1f%%',  # Display percentages
        startangle=90,  # Rotate the pie chart (start at the top)
        pctdistance=0.85,  # Distance of percentages from the center (default: 0.6)
        labeldistance=1.1,  # Distance of labels from the center (default: 1.1)
        textprops={'fontsize': 10})  # Adjust font size of labels

# Add a title
plt.title('Distribution of Male Members')

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
plt.figure(1, figsize=(8, 8))  # Increased figure size

# Define data
labels = file.MALE_MEMBERS.value_counts().index  # Labels for the pie chart
counts = file.MALE_MEMBERS.value_counts().values  # Values for the pie chart

# Define explode values to separate slices
explode = [0.2, 0.1, 0, 0, 0, 0, 0]  # Explode the first two slices

# Define custom colors
colors = ['red', 'green', 'blue', 'cyan', 'magenta', 'yellow', 'black']

# Create a pie chart with customizations
plt.pie(counts,
        explode=explode,  # Explode specific slices
        labels=labels,  # Add labels
        colors=colors,  # Set custom colors
        autopct='%0.2f%%',  # Display percentages with 2 decimal places
        pctdistance=0.85,  # Distance of percentages from the center
        labeldistance=1.2,  # Distance of labels from the center
        shadow=True,  # Add shadow effect
        startangle=140,  # Rotate the pie chart (start at 140 degrees)
        radius=1,  # Radius of the pie chart (default: 1)
        counterclock=True,  # Plot slices counterclockwise
        wedgeprops={'linewidth': 2, 'edgecolor': 'black'},  # Customize wedge properties
        textprops={'fontsize': 14},  # Adjust font size of labels and percentages
        center=(0, 0),  # Center of the pie chart (default: (0, 0))
        frame=False,  # Remove the frame around the pie chart
        rotatelabels=True)  # Rotate labels to prevent overlap

# Add a title
plt.title("Male Members in the Household", fontsize=15, fontweight="bold")

# Add a legend
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1))  # Place legend outside the pie chart

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
plt.figure(1, figsize=(6, 6))  # Increased figure size

# Define data
labels = file.FEMALE_MEMBERS.value_counts().index  # Labels for the pie chart
counts = file.FEMALE_MEMBERS.value_counts().values  # Values for the pie chart

# Define custom colors
colors = ['skyblue', 'orange', 'lightgreen', 'pink', 'lightcoral']

# Create a donut chart
plt.pie(counts,
        labels=labels,  # Add labels
        colors=colors,  # Set custom colors
        autopct='%1.1f%%',  # Display percentages
        startangle=90,  # Rotate the pie chart (start at the top)
        pctdistance=0.85,  # Distance of percentages from the center
        labeldistance=1.1,  # Distance of labels from the center
        textprops={'fontsize': 12},  # Adjust font size of labels
        radius=1.2)  # Outer radius of the pie chart

# Add a white circle in the center to create a donut chart
plt.pie([1], colors='white', radius=0.6)  # Inner radius of the donut chart

# Add a title
plt.title('Distribution of Female Members', fontsize=15, fontweight='bold')

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create a figure with a larger size to accommodate the labels
plt.figure(1, figsize=(6, 6))  # Increased figure size

# Define data
male_counts = file.MALE_MEMBERS.value_counts()
female_counts = file.FEMALE_MEMBERS.value_counts()

# Get the union of all categories (unique values) from both male and female counts
categories = sorted(set(male_counts.index).union(set(female_counts.index)))

# Align male and female counts to the same categories
male_counts_aligned = [male_counts.get(cat, 0) for cat in categories]  # Male counts, default to 0 if category is missing
female_counts_aligned = [female_counts.get(cat, 0) for cat in categories]  # Female counts, default to 0 if category is missing

# Define custom colors
colors = ['red', 'green', 'blue', 'cyan', 'magenta', 'yellow', 'black']

# Create a nested pie chart
# Outer pie chart (Male members)
plt.pie(male_counts_aligned,
        labels=categories,  # Add labels
        colors=colors,  # Set custom colors
        autopct='%1.1f%%',  # Display percentages
        startangle=90,  # Rotate the pie chart (start at the top)
        pctdistance=0.85,  # Distance of percentages from the center
        labeldistance=1.1,  # Distance of labels from the center
        textprops={'fontsize': 12},  # Adjust font size of labels
        radius=1.2)  # Outer radius of the pie chart

# Inner pie chart (Female members)
plt.pie(female_counts_aligned,
        labels=categories,  # Add labels
        colors=colors,  # Set custom colors
        autopct='%1.1f%%',  # Display percentages
        startangle=90,  # Rotate the pie chart (start at the top)
        pctdistance=0.75,  # Distance of percentages from the center
        labeldistance=0.9,  # Distance of labels from the center
        textprops={'fontsize': 10},  # Adjust font size of labels
        radius=0.8)  # Inner radius of the pie chart

# Add a title
plt.title('Distribution of Male and Female Members', fontsize=15, fontweight='bold')

# Add padding between the plot elements and the figure edges
plt.tight_layout()

# Display the plot
plt.show()

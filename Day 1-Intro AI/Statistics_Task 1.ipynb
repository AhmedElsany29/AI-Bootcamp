# %% [markdown]
# ## Enter your name

# %%
# here

# %% [markdown]
# ### What is the meaning of statistics in your opinion?

# %%
# enter your answer here

# %% [markdown]
# ### What are the types of sampling in Statistics

# %%
# enter your answer here

# %% [markdown]
# ### What is the difference between the Ist quartile, the IInd quartile, and the IIIrd quartile?

# %%
# enter your answer here

# %% [markdown]
# ### What is an outlier?

# %%
# enter your answer here

# %% [markdown]
# ![8255398bf8aa47a08b654d8089abf4c0.jpg](data:image/jpeg;base64,...)

# %%
# enter your answer here

# %% [markdown]
# ### What are the charts can represent the vales in product column ?

# %% [markdown]
# ![Screenshot 2023-02-03 214945.png](data:image/png;base64,...)

# %%
# enter your answer here

# %% [markdown]
# ### What is the chart can represent the distribution of total sales column ?

# %% [markdown]
# ![Screenshot 2023-02-03 215427.png](data:image/png;base64,...)

# %%
# enter your answer here

# %% [markdown]
# ### What are the measurements can describe and summarize the vales in operation profit column?

# %%
# enter your answer here

# %% [markdown]
# ### What are you understand and notice from the graph below ?

# %% [markdown]
# ![download (10).png](data:image/png;base64,...)

# %%
# enter your answer here

# %% [markdown]
# ### What are the methods to handle missing values?

# %%
# enter your answer here

# %% [markdown]
# ### In your opinion, what are the reasons for having missing values in the data?

# %%
# enter your answer here

# %% [markdown]
# ### What is the name of the graph below and what insights we discover from it?

# %% [markdown]
# ![bw5-56a8fa7d5f9b58b7d0f6e8be.gif](data:image/gif;base64,...)

# %%
# enter your answer here

# %% [markdown]
# ### What is the normal distribution means?

# %%
# enter your answer here

# %% [markdown]
# ### What is the meaning of "the most popular response or value in the data set."

# %%
# enter your answer here

# %% [markdown]
# ### What is the meaning of "  the average distance between each value in your data set and the mean."

# %%
# enter your answer here
